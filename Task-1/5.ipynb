# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x=[800,1000,2000]
y=[640160,10002000,40004000]
plt.plot(x,y)
plt.title(" prices against the size of houses")
plt.xlabel("size of houses in sq feet")
plt.ylabel("price of the house")
# Out:
# Text(0, 0.5, 'price of the house')

# %%
sno = [1,2,3]
sqf = [800,1000,2000]
prc = [6401600,10002000,40004000]
   
 
dict = {'serial_no': sno, 'square_feet': sqf, 'price': prc} 
     
df = pd.DataFrame(dict)
  

df.to_csv(r'H:\01 SIVARAMAN\COGNIZANCE\AI\Task 1\a.csv', index=False)
